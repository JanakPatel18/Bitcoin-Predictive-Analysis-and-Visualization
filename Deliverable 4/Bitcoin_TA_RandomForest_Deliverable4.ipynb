# %%
# Import Libraries
import numpy as np  # to handle matrix
import pandas as pd # to handle data
from matplotlib import pyplot as plt # to visualize
import datetime, pytz # to handle time

from sklearn.model_selection import train_test_split # Split data
from sklearn.ensemble import RandomForestRegressor # Random Forest Classifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import plot_confusion_matrix

# %%
# Declare variable to keep Database & connection name along with source flat file name
DatabaesName = 'CRYPTO'
collection_raw = 'CRYPTO_RAW_DATA'
collection_name = 'CRYPTO_DATA_FEED'
# filepath = r"Data\bitstampUSD.csv" 
# Creating MongoDB connection object
mng_client = pymongo.MongoClient("mongodb+srv://group3:1goodday@cluster0.cep5x.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")
#create Database object
mng_db = mng_client[DatabaesName] 
#Create Collection object with-in Database for raw data
#db_cm_raw = mng_db[collection_raw]
#Create Collection object with-in Database
db_cm = mng_db[collection_name]

# %%
# Read data from Mongo DB to Pandas DataFrame
Bit_df = pd.DataFrame(list(db_cm.find()))

# %%
df = pd.read_csv('bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv')
df.head(3)
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price
# 0            4.39
# 1             NaN
# 2             NaN

# %%
from datetime import datetime 
df.Timestamp = pd.to_datetime(df.Timestamp, unit='s')
df['Timestamp '] = df['Timestamp'].values.astype(dtype='datetime64[ms]')

# Resampling to daily frequency
df.index = df.Timestamp
df = df.resample('D').mean()
df.head()
# Out:
#                 Open      High       Low     Close  Volume_(BTC)  \
# Timestamp
# 2011-12-31  4.465000  4.482500  4.465000  4.482500     23.829470
# 2012-01-01  4.806667  4.806667  4.806667  4.806667      7.200667
# 2012-01-02  5.000000  5.000000  5.000000  5.000000     19.048000
# 2012-01-03  5.252500  5.252500  5.252500  5.252500     11.004660
# 2012-01-04  5.200000  5.223333  5.200000  5.223333     11.914807
#
#             Volume_(Currency)  Weighted_Price
# Timestamp
# 2011-12-31         106.330084        4.471603
# 2012-01-01          35.259720        4.806667
# 2012-01-02          95.240000        5.000000
# 2012-01-03          58.100651        5.252500
# 2012-01-04          63.119577        5.208159

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3379 entries, 2011-12-31 to 2021-03-31
# Freq: D
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Open               3376 non-null   float64
#  1   High               3376 non-null   float64
#  2   Low                3376 non-null   float64
#  3   Close              3376 non-null   float64
#  4   Volume_(BTC)       3376 non-null   float64
#  5   Volume_(Currency)  3376 non-null   float64
#  6   Weighted_Price     3376 non-null   float64
# dtypes: float64(7)
# memory usage: 211.2 KB

# %%
daily_df = df

# %%
# Volume is single event so fill "NaN"s with zeroes for relevant fields
daily_df['Volume_(BTC)'].fillna(value=0, inplace=True)
daily_df['Volume_(Currency)'].fillna(value=0, inplace=True)
daily_df['Weighted_Price'].fillna(value=0, inplace=True)


# (open, high, low, close) data which is a continuous timeseries so 'fill forwards' those values
daily_df['Open'].fillna(method='ffill', inplace=True)
daily_df['High'].fillna(method='ffill', inplace=True)
daily_df['Low'].fillna(method='ffill', inplace=True)
daily_df['Close'].fillna(method='ffill', inplace=True)

print("Shape: ", daily_df.shape)
print("Columns= ", daily_df.columns)
print("Is There any 'NaN' value: ", daily_df.isnull().values.any())
print("Is there any duplicate value: ", daily_df.index.duplicated().any())
# Out:
# Shape:  (3379, 7)
# Columns=  Index(['Open', 'High', 'Low', 'Close', 'Volume_(BTC)', 'Volume_(Currency)',
#        'Weighted_Price'],
#       dtype='object')
# Is There any 'NaN' value:  False
# Is there any duplicate value:  False

# %%
# There is a library called ta, which creates many technical indicators, like moving averages(and many more). 
# It is originally designed for analyzing stock data, but also works for Bitcoin. 
# It adds more than 80 features to the dataset.

# %%
from ta import add_all_ta_features
from ta.utils import dropna

pd.set_option('display.max_columns', None)

df = dropna(daily_df)
df = add_all_ta_features(
    daily_df, open="Open", high="High", low="Low", close="Close", volume="Volume_(BTC)")

df = daily_df.fillna(0)
df.tail()
# Out:
# /Users/hebymathew/opt/anaconda3/lib/python3.8/site-packages/ta/trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /Users/hebymathew/opt/anaconda3/lib/python3.8/site-packages/ta/trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
#                     Open          High           Low         Close  \
# Timestamp
# 2021-03-27  55193.240643  55219.665031  55168.757372  55195.415367
# 2021-03-28  55833.608471  55857.735342  55810.425126  55835.012863
# 2021-03-29  56914.886595  56946.213593  56885.242967  56915.629993
# 2021-03-30  58347.805624  58371.955310  58323.956690  58349.357087
# 2021-03-31  58767.750000  58778.180000  58755.970000  58778.180000
#
#             Volume_(BTC)  Volume_(Currency)  Weighted_Price  volume_adi  \
# Timestamp
# 2021-03-27      1.823877      100884.732367    55193.357260  113.490059
# ...

# %%
# create the classes we want to predict looking 7 days into the future
y = (df['Close'].shift(periods = -7,fill_value = 0) - df['Close'])
y = (y > 0)

#remove last 7 rows, because of the shift
x = df[:-7]
y = y[:-7]

x.shape,y.shape
# Out:
# ((3372, 93), (3372,))

# %% [markdown]
# ### Step 1: Split Input Data into Training and Test Sets

# %%
# To divide the dataset into test and training data, the First 3000 days for training 
# and the remaining 371 days for testing.

# number of training instances
num_test = 371 
x_train = x[:-num_test]
y_train = y[:-num_test]
x_test = x[-num_test:]
y_test = y[-num_test:]

# %% [markdown]
# ### Step 2: Fit Classification Model to Training Set

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_depth=4, random_state=17)
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=4, random_state=17)

# %% [markdown]
# ### Step 3: Apply Model to the Test Set

# %%
res = clf.predict(x_test)
acc = (res== y_test.values).mean()
print(acc)
# Out:
# 0.40700808625336926

# %%
# Step 4: Interpretation
# The red and green dots indicate whether the prediction was correct at the given time or not

# %%
# %matplotlib inline
import  matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]
colors = ['green' if x else 'red' for x in res== y_test]
plt.title('Interpretation - Open Price Vs Year')
ax = plt.gca()
ax.plot(x_test['Open'],lw = 1, c = 'black')
x_test.reset_index().plot.scatter( x = 'Timestamp', y = 'Open',color = colors,s = 8,ax= ax)
ax.xaxis.set_major_locator(plt.MaxNLocator(10))

# %%
# Random forest is a supervised learning algorithm that is an ensemble of a decision tree.

# %% [raw]
# # Description of data preprocessing
#
# For the preliminary data preprocessing, csv was used as an overview of the dataset downloaded from kaggle. Features with null values were dropped. The dataset was resampled to include daily timestamp instead of minutes. Most of the values were highly numerical with one being timestamp variable.
#
# # Description of feature engineering and the feature selection, including the decision-making process
#
# For our preliminary features, we decided to first use all of the attributes of the bitcoin, including Open, High, Close, Volume_BTC, weighted Price and Volume_Currency. We added in additional features, including momentum_rsi and volatility to see if the added features would improve the model.

# %% [raw]
# # Description of how data was split into training and testing sets
#
# Training and testing sets were split up using an 80/20 approach. This was because the dataset contained over 3000 values allowing us to train our model with plenty of values while still maintaining enough to test with.

# %% [raw]
# # Explanation of model choice, including limitations and benefits
#
# We decided to use supervised machine learning model as we already know the target outcome that we are trying to predict (in other words the outcome is discrete). Whether or not we can predict a future value based on the available data.
#
# Due to feature size of dataset, it allowed multiple weak learners to create a more accurate and robust prediction engine model. Also, it helps in dealing with overfitting.

# %% [raw]
# # Description of how they have trained the model thus far, and any additional training that will take place.
#
# We used all the features of our dataset and replaced null values with the mean values for specific features, made our training values all numerical values, and encoded our features to be binary.

# %% [raw]
# # Description of current accuracy score
#
# Our accuracy was low, only 41%. So we decided to move ahead with times-series forecasting.
